# %% [markdown]
# ### **Title:** Non-Linear Neural Network for Binary Classification

# %% [markdown]
# #### **Objective:** To improve model with ReLU Activation(ModelV2)

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import pandas as pd

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
df = pd.read_csv(r'binary_classification_moons.csv')
df.head(6)
# Out:
#          X1        X2  label
# 0 -0.009332  0.390981      1
# 1  0.954574 -0.473756      1
# 2  0.918526 -0.425196      1
# 3  0.412768 -0.376385      1
# 4 -0.845320  0.528799      0
# 5  0.579542 -0.352979      1

# %%
df.describe()
# Out:
#                 X1           X2       label
# count  1000.000000  1000.000000  1000.00000
# mean      0.499552     0.249196     0.50000
# std       0.867371     0.494822     0.50025
# min      -1.061751    -0.571697     0.00000
# 25%      -0.019860    -0.216408     0.00000
# 50%       0.502008     0.248686     0.50000
# 75%       1.020851     0.694288     1.00000
# max       2.064637     1.042677     1.00000

# %%
# Visualize with a plot
import matplotlib.pyplot as plt
plt.scatter(
            x=df.X1,
            y=df.X2,
            c=df.label,
            cmap=plt.cm.RdYlBu
            );

# %%
# vectorizing X1 and X2 into a single tensor/nparray

X = df[['X1', 'X2']].values
y = df['label'].values

# %%
print(f"First 5 X features:\n{X[:5]}")
print(f"\nFirst 5 y labels:\n{y[:5]}")
# Out:
# First 5 X features:
# [[-0.00933187  0.39098105]
#  [ 0.95457387 -0.47375583]
#  [ 0.9185256  -0.42519648]
#  [ 0.41276802 -0.37638459]
#  [-0.84532016  0.52879908]]
#
# First 5 y labels:
# [1 1 1 1 0]

# %%
# Check the shapes of our features and labels
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# Turn data into tensors
# Otherwise this causes issues with computations later on
import torch
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

# View the first five samples
X[:5], y[:5]
# Out:
# C:\Users\Lenovo LOQ\AppData\Local\Temp\ipykernel_22448\3536051194.py:5: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:219.)
#   y = torch.from_numpy(y).type(torch.float)
# (tensor([[-0.0093,  0.3910],
#          [ 0.9546, -0.4738],
#          [ 0.9185, -0.4252],
#          [ 0.4128, -0.3764],
#          [-0.8453,  0.5288]]),
#  tensor([1., 1., 1., 1., 0.]))

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2, # 20% test, 80% train
                                                    random_state=42) # make the random split reproducible

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (800, 200, 800, 200)

# %%
# 1. Construct a model class that subclasses nn.Module
class ModelV0(nn.Module):
    def __init__(self):
        super().__init__()
        # 2. Create 2 nn.Linear layers capable of handling X and y input and output shapes
        self.layer_1 = nn.Linear(in_features=2, out_features=5) # takes in 2 features (X), produces 5 features
        self.layer_2 = nn.Linear(in_features=5, out_features=1) # takes in 5 features, produces 1 feature (y)

    # 3. Define a forward method containing the forward pass computation
    def forward(self, x):
        # Return the output of layer_2, a single feature, the same shape as y
        return self.layer_2(self.layer_1(x)) # computation goes through layer_1 first then the output of layer_1 goes through layer_2

# 4. Create an instance of the model and send it to target device
model_0 = ModelV0().to(device)
model_0
# Out:
# ModelV0(
#   (layer_1): Linear(in_features=2, out_features=5, bias=True)
#   (layer_2): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
model = model_0

# %%
# Make predictions with the model
untrained_preds = model(X_test.to(device))
print(f"Length of predictions: {len(untrained_preds)}, Shape: {untrained_preds.shape}")
print(f"Length of test samples: {len(y_test)}, Shape: {y_test.shape}")
print(f"\nFirst 10 predictions:\n{untrained_preds[:10]}")
print(f"\nFirst 10 test labels:\n{y_test[:10]}")
# Out:
# Length of predictions: 200, Shape: torch.Size([200, 1])
# Length of test samples: 200, Shape: torch.Size([200])
#
# First 10 predictions:
# tensor([[0.4349],
#         [0.8500],
#         [0.8735],
#         [0.8058],
#         [1.3645],
#         [1.4693],
#         [0.8969],
#         [0.8700],
#         [0.7968],
#         [0.8216]], grad_fn=<SliceBackward0>)
#
# First 10 test labels:
# tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.])

# %%
# Create a loss function
# loss_fn = nn.BCELoss() # BCELoss = no sigmoid built-in
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer
optimizer = torch.optim.SGD(params=model.parameters(),
                            lr=0.1)

# %%
# View the frist 5 outputs of the forward pass on the test data
y_logits = model(X_test.to(device))[:5]
y_logits
# Out:
# tensor([[0.4349],
#         [0.8500],
#         [0.8735],
#         [0.8058],
#         [1.3645]], grad_fn=<SliceBackward0>)

# %%
# Use sigmoid on model logits
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs
# Out:
# tensor([[0.6070],
#         [0.7006],
#         [0.7055],
#         [0.6912],
#         [0.7965]], grad_fn=<SigmoidBackward0>)

# %%
# Find the predicted labels (round the prediction probabilities)
y_preds = torch.round(y_pred_probs)

# In full
y_pred_labels = torch.round(torch.sigmoid(model(X_test.to(device))[:5]))

# Check for equality
print(torch.eq(y_preds.squeeze(), y_pred_labels.squeeze()))

# Get rid of extra dimension
y_preds.squeeze()
# Out:
# tensor([True, True, True, True, True])
# tensor([1., 1., 1., 1., 1.], grad_fn=<SqueezeBackward0>)

# %%
y_test[:5]
# Out:
# tensor([1., 0., 1., 0., 1.])

# %%
torch.manual_seed(42)

# Set the number of epochs
epochs = 100

# Put data to target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
from utils import train_and_test_loop
train_losses, acc_list, test_losses, test_acc = train_and_test_loop(
    model=model,
    epochs=epochs,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    loss_fn=loss_fn,
    optimizer=optimizer
)
# Out:
# Epoch: 0 | Loss: 0.64830, Accuracy: 64.88% | Test loss: 0.65802, Test acc: 64.00%
# Epoch: 10 | Loss: 0.55748, Accuracy: 71.38% | Test loss: 0.57245, Test acc: 64.50%
# Epoch: 20 | Loss: 0.50146, Accuracy: 76.38% | Test loss: 0.51870, Test acc: 69.50%
# Epoch: 30 | Loss: 0.45357, Accuracy: 78.62% | Test loss: 0.47324, Test acc: 73.50%
# Epoch: 40 | Loss: 0.41433, Accuracy: 80.12% | Test loss: 0.43580, Test acc: 75.50%
# Epoch: 50 | Loss: 0.38380, Accuracy: 81.12% | Test loss: 0.40606, Test acc: 77.50%
# Epoch: 60 | Loss: 0.36038, Accuracy: 81.88% | Test loss: 0.38254, Test acc: 77.50%
# Epoch: 70 | Loss: 0.34218, Accuracy: 82.50% | Test loss: 0.36364, Test acc: 78.50%
# Epoch: 80 | Loss: 0.32770, Accuracy: 83.25% | Test loss: 0.34809, Test acc: 81.00%
# Epoch: 90 | Loss: 0.31587, Accuracy: 84.12% | Test loss: 0.33499, Test acc: 81.50%

# %%
from utils import local_plot_boundary

# Plot decision boundaries for training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
local_plot_boundary(model, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
local_plot_boundary(model, X_test, y_test)

# %%
def plot_loss_curves(train_losses, test_losses):
    """
    Plots training and testing loss curves.

    Args:
        train_losses (list): Loss values from training
        test_losses (list): Loss values from testing
    """
    epochs = range(len(train_losses))

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, train_losses, label="Training Loss")
    plt.plot(epochs, test_losses, label="Test Loss")

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training and Test Loss Curves")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_loss_curves(train_losses, test_losses)

# %%
class ModelV1(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.layer_3 = nn.Linear(in_features=10, out_features=1)

    def forward(self, x): # note: always make sure forward is spelt correctly!
        # Creating a model like this is the same as below, though below
        # generally benefits from speedups where possible.
        # z = self.layer_1(x)
        # z = self.layer_2(z)
        # z = self.layer_3(z)
        # return z
        return self.layer_3(self.layer_2(self.layer_1(x)))

model_1 = ModelV1().to(device)
model_1
# Out:
# ModelV1(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (layer_3): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
model = model_1
epochs = 1000

# Create a loss function
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer
optimizer = torch.optim.SGD(params=model.parameters(),
                            lr=0.1)

# %%
train_losses, acc_list, test_losses, test_acc = train_and_test_loop(
    model=model,
    epochs=epochs,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    loss_fn=loss_fn,
    optimizer=optimizer
)

# Plot decision boundaries for training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
local_plot_boundary(model, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
local_plot_boundary(model, X_test, y_test)
# Out:
# Epoch: 0 | Loss: 0.71976, Accuracy: 30.75% | Test loss: 0.70134, Test acc: 45.50%
# Epoch: 10 | Loss: 0.58674, Accuracy: 79.62% | Test loss: 0.58552, Test acc: 78.00%
# Epoch: 20 | Loss: 0.47594, Accuracy: 79.62% | Test loss: 0.48700, Test acc: 77.00%
# Epoch: 30 | Loss: 0.39832, Accuracy: 81.00% | Test loss: 0.41841, Test acc: 77.00%
# Epoch: 40 | Loss: 0.35499, Accuracy: 81.62% | Test loss: 0.37773, Test acc: 78.00%
# Epoch: 50 | Loss: 0.32886, Accuracy: 82.62% | Test loss: 0.35055, Test acc: 80.50%
# Epoch: 60 | Loss: 0.31010, Accuracy: 83.75% | Test loss: 0.32940, Test acc: 82.00%
# Epoch: 70 | Loss: 0.29513, Accuracy: 84.75% | Test loss: 0.31171, Test acc: 83.50%
# Epoch: 80 | Loss: 0.28276, Accuracy: 85.00% | Test loss: 0.29670, Test acc: 85.50%
# Epoch: 90 | Loss: 0.27260, Accuracy: 85.62% | Test loss: 0.28413, Test acc: 86.50%
| Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23719, Test acc: 89.50%
# Epoch: 390 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23717, Test acc: 89.50%
# Epoch: 400 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23715, Test acc: 89.50%
# Epoch: 410 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23714, Test acc: 89.50%
# Epoch: 420 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23713, Test acc: 89.50%
# Epoch: 430 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23712, Test acc: 89.00%
# Epoch: 440 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23711, Test acc: 89.00%
# Epoch: 450 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23710, Test acc: 89.00%
# Epoch: 460 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23709, Test acc: 89.00%
# Epoch: 470 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23709, Test acc: 89.00%
# Epoch: 480 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23708, Test acc: 89.00%
# Epoch: 490 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23708, Test acc: 89.00%
# Epoch: 500 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23707, Test acc: 89.00%
# Epoch: 510 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23707, Test acc: 89.00%
# Epoch: 520 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23707, Test acc: 89.00%
# Epoch: 530 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23707, Test acc: 89.00%
# Epoch: 540 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 550 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 560 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 570 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 580 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 590 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 600 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 610 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 620 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23706, Test acc: 89.00%
# Epoch: 630 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 640 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 650 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 660 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 670 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 680 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 690 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 700 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 710 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 720 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 730 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 740 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 750 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 760 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 770 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 780 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 790 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 800 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 810 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 820 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 830 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 840 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 850 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 860 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 870 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 880 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 890 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 900 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 910 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 920 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 930 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 940 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 950 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 960 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 970 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 980 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%
# Epoch: 990 | Loss: 0.23940, Accuracy: 88.88% | Test loss: 0.23705, Test acc: 89.00%

# %%
plot_loss_curves(train_losses, test_losses)

# %% [markdown]
# #### Build a model with non-linear activation functions
# To improve our model's ability to learn non-linear patterns, we can add a non-linear activation function, such as nn.ReLU() or nn.Sigmoid(), between the linear layers. Let's create ModelV2 with nn.ReLU().

# %%
# Build a model with non-linear activation functions
class ModelV2(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.relu = nn.ReLU() # Our first non-linear activation function
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.relu_2 = nn.ReLU() # Our second non-linear activation function
        self.layer_3 = nn.Linear(in_features=10, out_features=1)

    def forward(self, x):
        # Pass the input through the layers and activation functions
        return self.layer_3(self.relu_2(self.layer_2(self.relu(self.layer_1(x)))))

# Instantiate ModelV2 and send it to the target device
model_2 = ModelV2().to(device)
model_2
# Out:
# ModelV2(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (relu): ReLU()
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (relu_2): ReLU()
#   (layer_3): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
# Reassign model, set epochs, loss function, and optimizer
model = model_2
epochs = 1000 # Keeping the same number of epochs for comparison

# Create a loss function (same as before)
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer (same as before)
optimizer = torch.optim.SGD(params=model.parameters(),
                            lr=0.1)

print(f"Training {model.__class__.__name__} for {epochs} epochs...")
# Out:
# Training ModelV2 for 1000 epochs...

# %%
# Train and test the new model
train_losses_v2, acc_list_v2, test_losses_v2, test_acc_v2 = train_and_test_loop(
    model=model,
    epochs=epochs,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
# Epoch: 820 | Loss: 0.01982, Accuracy: 100.00% | Test loss: 0.01890, Test acc: 100.00%
# Epoch: 830 | Loss: 0.01919, Accuracy: 100.00% | Test loss: 0.01829, Test acc: 100.00%
# Epoch: 840 | Loss: 0.01860, Accuracy: 100.00% | Test loss: 0.01771, Test acc: 100.00%
# Epoch: 850 | Loss: 0.01803, Accuracy: 100.00% | Test loss: 0.01716, Test acc: 100.00%
# Epoch: 860 | Loss: 0.01749, Accuracy: 100.00% | Test loss: 0.01663, Test acc: 100.00%
# Epoch: 870 | Loss: 0.01697, Accuracy: 100.00% | Test loss: 0.01613, Test acc: 100.00%
# Epoch: 880 | Loss: 0.01648, Accuracy: 100.00% | Test loss: 0.01565, Test acc: 100.00%
# Epoch: 890 | Loss: 0.01602, Accuracy: 100.00% | Test loss: 0.01520, Test acc: 100.00%
# Epoch: 900 | Loss: 0.01557, Accuracy: 100.00% | Test loss: 0.01476, Test acc: 100.00%
# Epoch: 910 | Loss: 0.01515, Accuracy: 100.00% | Test loss: 0.01435, Test acc: 100.00%
# Epoch: 920 | Loss: 0.01474, Accuracy: 100.00% | Test loss: 0.01395, Test acc: 100.00%
# Epoch: 930 | Loss: 0.01435, Accuracy: 100.00% | Test loss: 0.01358, Test acc: 100.00%
# Epoch: 940 | Loss: 0.01398, Accuracy: 100.00% | Test loss: 0.01322, Test acc: 100.00%
# Epoch: 950 | Loss: 0.01362, Accuracy: 100.00% | Test loss: 0.01287, Test acc: 100.00%
# Epoch: 960 | Loss: 0.01328, Accuracy: 100.00% | Test loss: 0.01254, Test acc: 100.00%
# Epoch: 970 | Loss: 0.01296, Accuracy: 100.00% | Test loss: 0.01222, Test acc: 100.00%
# Epoch: 980 | Loss: 0.01264, Accuracy: 100.00% | Test loss: 0.01192, Test acc: 100.00%
# Epoch: 990 | Loss: 0.01234, Accuracy: 100.00% | Test loss: 0.01163, Test acc: 100.00%

# %%
# Plot decision boundaries for training and test sets of ModelV2
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train (ModelV2)")
local_plot_boundary(model, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test (ModelV2)")
local_plot_boundary(model, X_test, y_test)
plt.suptitle(f"Decision Boundaries for {model.__class__.__name__}", y=1.02)
# Out:
# Text(0.5, 1.02, 'Decision Boundaries for ModelV2')

# %%
# Plot loss curves for ModelV2
plot_loss_curves(train_losses_v2, test_losses_v2)
plt.suptitle(f"Loss Curves for {model.__class__.__name__}", y=1.02)
# Out:
# Text(0.5, 1.02, 'Loss Curves for ModelV2')

# %% [markdown]
# The LinearRegressionNN model is not appropriate for the binary_classification_moons.csv dataset because the data contains complex, non-linear patterns that cannot be effectively classified using a simple linear boundary. ModelV0 achieved reasonable results (approximately 86-89% accuracy), but its performance was restricted because it lacked activation functions capable of capturing non-linear relationships. By improving the architecture and introducing ReLU activation functions in ModelV2, the network was able to identify the complex patterns within the dataset and reached 100% test accuracy. Hence, ModelV2 provides the best architecture for solving the moon-shaped classification problem.
